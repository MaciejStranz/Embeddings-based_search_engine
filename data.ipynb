# %%
import pandas as pd

splits = {'train': 'data/train-00000-of-00001.parquet', 'test': 'data/test-00000-of-00001.parquet', 'valid': 'data/valid-00000-of-00001.parquet'}
df_matches_train = pd.read_parquet("hf://datasets/CoIR-Retrieval/cosqa/" + splits["train"])
df_matches_test = pd.read_parquet("hf://datasets/CoIR-Retrieval/cosqa/" + splits["test"])
df_matches_valid = pd.read_parquet("hf://datasets/CoIR-Retrieval/cosqa/" + splits["valid"])
df_corpus = pd.read_parquet("hf://datasets/CoIR-Retrieval/cosqa/corpus/corpus-00000-of-00001.parquet")
df_queries = pd.read_parquet("hf://datasets/CoIR-Retrieval/cosqa/queries/queries-00000-of-00001.parquet")

# %%
df_corpus
# Out:
#           _id partition                                               text  \
# 0          d1     train  def writeBoolean(self, n):\n        """\n     ...
# 1          d2     train  def paste(xsel=False):\n    """Returns system ...
# 2          d3     train  def _format_json(data, theme):\n    """Pretty ...
# 3          d4     train  def create_path(path):\n    """Creates a absol...
# 4          d5     train  def _vector_or_scalar(x, type='row'):\n    """...
# ...       ...       ...                                                ...
# 20599  d20600      test  def genfirstvalues(cursor: Cursor, arraysize: ...
# 20600  d20601      test  def clean_column_names(df: DataFrame) -> DataF...
# 20601  d20602      test  def astensor(array: TensorLike) -> BKTensor:\n...
# 20602  d20603      test  def list_to_csv(value):\n    """\n    Converts...
# 20603  d20604      test  def _unzip_handle(handle):\n    """Transparent...
#
#       title language     meta_information
# ...
